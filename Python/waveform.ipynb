# %%
import serial
import time

# Define the commands
commands = [
    "+0.08", "+0.06", "+0.01", "-0.04", "-0.06", "-0.06", "-0.04",
    "+0.01", "+0.05", "+0.08", "+0.08", "+0.05", "+0.01", "-0.04", "-0.07",
    "-0.07", "-0.04", "+0.00", "+0.05", "+0.07", "+0.07", "+0.04", "-0.00",
    "-0.05", "-0.08", "-0.08", "-0.05", "-0.01", "+0.04", "+0.07", "+0.07",
    "+0.04", "-0.01", "-0.05", "-0.08", "-0.08", "-0.05", "-0.01", "+0.04",
    "+0.06", "+0.06", "+0.04", "-0.01", "-0.05", "-0.08", "-0.08", "-0.05",
    "-0.01", "+0.04", "+0.07", "+0.07", "+0.04", "-0.01", "-0.05", "-0.08",
    "-0.08", "-0.05", "-0.00", "+0.04", "+0.07", "+0.07", "+0.05", "+0.00",
    "-0.04", "-0.07", "-0.07", "-0.04", "+0.01", "+0.05", "+0.08", "+0.08",
    "+0.05", "+0.01", "-0.04", "-0.06", "-0.06", "-0.04", "+0.01", "+0.06",
    "+0.08", "+0.08", "+0.06", "+0.01", "-0.04", "-0.06", "-0.06", "-0.04",
    "+0.01", "+0.05", "+0.08", "+0.08", "+0.05", "+0.01", "-0.04", "-0.07",
    "-0.07", "-0.04", "+0.00", "+0.05", "+0.07", "+0.07", "+0.04", "-0.00",
    "-0.05", "-0.08", "-0.08", "-0.05", "-0.01", "+0.04", "+0.07", "+0.07",
    "+0.04", "-0.01", "-0.05", "-0.08", "-0.08", "-0.05", "-0.01", "+0.04"
]

# Open serial port
ser = serial.Serial('COM4', 115200)  # Change 'COM3' to your Arduino port
time.sleep(2)  # Wait for the serial connection to initialize

# Send commands
for command in commands:
    ser.write((command + '\n').encode())
    time.sleep(0.1)

ser.close()
